# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_auc_score
from IPython.display import FileLink

# %% [markdown]
# ## Loading the CSV file

# %%
raw="E_Commerce.csv"
df=pd.read_csv(raw)

# %% [markdown]
# ## Data Preprocessing

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10994    False
# 10995    False
# 10996    False
# 10997    False
# 10998    False
# Length: 10999, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=['ID'])

# %% [markdown]
# ## Feautre Engineering

# %%
df['Weight_Discount'] = df['Weight_in_gms'] * df['Discount_offered']
df['High_Discount'] = (df['Discount_offered'] > 20).astype(int)

df['Customer_Issue'] = (
    (df['Customer_care_calls'] >= 4) &
    (df['Customer_rating'] <= 2)
).astype(int)

df['Weight_Category'] = pd.cut(
    df['Weight_in_gms'],
    bins=[0, 2000, 4000, 6000, 10000],
    labels=['Light', 'Medium', 'Heavy', 'Very_Heavy']
)

# %% [markdown]
# ## One Hot Encoding

# %%
categorical_cols = [
    'Warehouse_block',
    'Mode_of_Shipment',
    'Product_importance',
    'Gender',
    'Weight_Category'
]

categorical_cols = [c for c in categorical_cols if c in df.columns]

df = pd.get_dummies(
    df,
    columns=categorical_cols,
    drop_first=True
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_care_calls         10999 non-null  int64
#  1   Customer_rating             10999 non-null  int64
#  2   Cost_of_the_Product         10999 non-null  int64
#  3   Prior_purchases             10999 non-null  int64
#  4   Discount_offered            10999 non-null  int64
#  5   Weight_in_gms               10999 non-null  int64
#  6   Reached.on.Time_Y.N         10999 non-null  int64
#  7   Weight_Discount             10999 non-null  int64
#  8   High_Discount               10999 non-null  int64
#  9   Customer_Issue              10999 non-null  int64
#  10  Warehouse_block_B           10999 non-null  bool
#  11  Warehouse_block_C           10999 non-null  bool
#  12  Warehouse_block_D           10999 non-null  bool
#  13  Warehouse_block_F           10999 non-null  bool
#  14  Mode_of_Shipment_Road       10999 non-null  bool
#  15  Mode_of_Shipment_Ship       10999 non-null  bool
#  16  Product_importance_low      10999 non-null  bool
#  17  Product_importance_medium   10999 non-null  bool
#  18  Gender_M                    10999 non-null  bool
#  19  Weight_Category_Medium      10999 non-null  bool
#  20  Weight_Category_Heavy       10999 non-null  bool
#  21  Weight_Category_Very_Heavy  10999 non-null  bool
# dtypes: bool(12), int64(10)
# memory usage: 988.3 KB

# %% [markdown]
# ## Define X and Y

# %%
X =df[['Customer_care_calls', 'Customer_rating', 'Cost_of_the_Product',
       'Prior_purchases', 'Discount_offered', 'Weight_in_gms','Warehouse_block_B', 'Warehouse_block_C',
       'Warehouse_block_D', 'Warehouse_block_F', 'Mode_of_Shipment_Road',
       'Mode_of_Shipment_Ship', 'Product_importance_low',
       'Product_importance_medium', 'Gender_M','Weight_Discount']]     
y = df['Reached.on.Time_Y.N']

# %% [markdown]
# ## Train-Test-Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42,stratify=y)

# %% [markdown]
# ## Scaling

# %%
numeric_cols = [
    'Customer_care_calls',
    'Customer_rating',
    'Cost_of_the_Product',
    'Prior_purchases',
    'Discount_offered',
    'Weight_in_gms',
    'Weight_Discount'
]

scaler = StandardScaler()

X_train[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %% [markdown]
# ## Logistic Regression Model

# %%
model = LogisticRegression(max_iter=1000,class_weight='balanced')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %% [markdown]
# ## Probability Prediction

# %%
y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > 0.4).astype(int)

# %% [markdown]
# ## Evaluation

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 866  465]
#  [ 706 1263]]

# %%
classification_rep=classification_report(y_test,y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.65      0.60      1331
#            1       0.73      0.64      0.68      1969
#
#     accuracy                           0.65      3300
#    macro avg       0.64      0.65      0.64      3300
# weighted avg       0.66      0.65      0.65      3300

# %%
FileLink("E_Commerce_PowerBI.csv")
# Out:
# C:\Users\oanka\E_Commerce_PowerBI.csv

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\oanka'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.bundle',
#  '.cache',
#  '.cisco',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.docker',
#  '.dotnet',
#  '.expo',
#  '.idlerc',
#  '.insomniac',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.local',
#  '.m2',
#  '.matplotlib',
#  '.ms-ad',
#  '.spyder-py3',
#  '.streamlit',
#  '.templateengine',
#  '.virtual_documents',
#  '.vscode',
#  '.vscode-print-resource-cache',
#  '3D Objects',
#  'anaconda3',
#  'anaconda_projects',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'ARIMA.ipynb',
#  'Audio-Text.ipynb',
#  'breast_cancer_data.csv',
#  'CapStone_Decision_Tree.ipynb',
#  'CapStone_LogisticRegression.ipynb',
#  'Capstone_Project_EDA.ipynb',
#  'Capstone_Project_KNN.ipynb',
#  'Capstone_Project_RandomForest.ipynb',
#  'cars_data-1-1.csv',
#  'Contacts',
#  'Cookies',
#  'Create Visualizations using Matplotlib, Seaborn & Folium.ipynb',
#  'customer_segmentation.csv',
#  'data',
#  'Data_Science_1.ipynb',
#  'Data_Science_2.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Dropbox',
#  'ecommerce_sales_analysis.ipynb',
#  'Excercise_Python_________.ipynb',
#  'E_Commerce.csv',
#  'E_Commerce_PowerBI.csv',
#  'Favorites',
#  'flappy-bird-rn',
#  'Gradient_Boosting.ipynb',
#  'Housing-2-1.csv',
#  'Housing-Sales-Analysis.ipynb',
#  'housing.csv',
#  'IntelGraphicsProfiles',
#  'iris.csv',
#  'Jedi',
#  'KNN.ipynb',
#  'K_Fold_Cross_Validation.ipynb',
#  'Linear-Regression-Student-Performance-1.ipynb',
#  'Links',
#  'Local Settings',
#  'Logistic_Regression.ipynb',
#  'Machine_Learning.ipynb',
#  'Microsoft',
#  'mnist.csv',
#  'Module 6 Excercise.ipynb',
#  'Multiple_Logistic_Regression.ipynb',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{68f31326-af3c-11ef-a969-da43caba261a}.TM.blf',
#  'NTUSER.DAT{68f31326-af3c-11ef-a969-da43caba261a}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{68f31326-af3c-11ef-a969-da43caba261a}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'output.mp3',
#  'outputs',
#  'output_plots',
#  'Pictures',
#  'PrintHood',
#  'Random_Forest_Classifier.ipynb',
#  'Recent',
#  'Sample - Superstore.csv',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'source',
#  'spam.csv',
#  'Standard_Scaler.ipynb',
#  'Start Menu',
#  'Super Store Sales Aanalysis.ipynb',
#  'Superstore.csv',
#  'SVM.ipynb',
#  'Telco_Customer_Churn.csv',
#  'temperature-1.csv',
#  'Templates',
#  'Text-Preprocessing-NLP.ipynb',
#  'Text_Classification.ipynb',
#  'Titanic-Dataset.csv',
#  'Titanic_Data_Analysis.ipynb',
#  'titanic_submission.csv',
#  'Twitter_Data.csv',
#  'Untitled Folder',
#  'Untitled Folder 1',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Videos']

# %%
df.head()
# Out:
#    Customer_care_calls  Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    4                2                  177                3
# 1                    4                5                  216                2
# 2                    2                2                  183                4
# 3                    3                3                  176                4
# 4                    2                2                  184                3
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N  Weight_Discount  \
# 0                44           1233                    1            54252
# 1                59           3088                    1           182192
# 2                48           3374                    1           161952
# 3                10           1177                    1            11770
# 4                46           2484                    1           114264
#
#    High_Discount  Customer_Issue  ...  Warehouse_block_D  Warehouse_block_F  \
# 0              1               1  ...               True              False
# 1              1               0  ...              False               True
# 2              1               0  ...              False              False
# 3              0               0  ...              False              False
# 4              1               0  ...              False              False
#
#    Mode_of_Shipment_Road  Mode_of_Shipment_Ship  Product_importance_low  \
# 0                  False                  False                    True
# 1                  False                  False                    True
# 2                  False                  False                    True
# 3                  False                  False                   False
# 4                  False                  False                   False
#
#    Product_importance_medium  Gender_M  Weight_Category_Medium  \
# 0                      False     False                   False
# 1                      False      True                    True
# 2                      False      True                    True
# 3                       True      True                   False
# 4                       True     False                    True
#
#    Weight_Category_Heavy  Weight_Category_Very_Heavy
# 0                  False                       False
# 1                  False                       False
# 2                  False                       False
# 3                  False                       False
# 4                  False                       False
#
# [5 rows x 22 columns]

# %%
df.to_csv("E_Commerce_PowerBI.csv", index=False)

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.bundle',
#  '.cache',
#  '.cisco',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.docker',
#  '.dotnet',
#  '.expo',
#  '.idlerc',
#  '.insomniac',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.local',
#  '.m2',
#  '.matplotlib',
#  '.ms-ad',
#  '.spyder-py3',
#  '.streamlit',
#  '.templateengine',
#  '.virtual_documents',
#  '.vscode',
#  '.vscode-print-resource-cache',
#  '3D Objects',
#  'anaconda3',
#  'anaconda_projects',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'ARIMA.ipynb',
#  'Audio-Text.ipynb',
#  'breast_cancer_data.csv',
#  'CapStone_Decision_Tree.ipynb',
#  'CapStone_LogisticRegression.ipynb',
#  'Capstone_Project_EDA.ipynb',
#  'Capstone_Project_KNN.ipynb',
#  'Capstone_Project_RandomForest.ipynb',
#  'cars_data-1-1.csv',
#  'Contacts',
#  'Cookies',
#  'Create Visualizations using Matplotlib, Seaborn & Folium.ipynb',
#  'customer_segmentation.csv',
#  'data',
#  'Data_Science_1.ipynb',
#  'Data_Science_2.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Dropbox',
#  'ecommerce_sales_analysis.ipynb',
#  'Excercise_Python_________.ipynb',
#  'E_Commerce.csv',
#  'E_Commerce_PowerBI.csv',
#  'Favorites',
#  'flappy-bird-rn',
#  'Gradient_Boosting.ipynb',
#  'Housing-2-1.csv',
#  'Housing-Sales-Analysis.ipynb',
#  'housing.csv',
#  'IntelGraphicsProfiles',
#  'iris.csv',
#  'Jedi',
#  'KNN.ipynb',
#  'K_Fold_Cross_Validation.ipynb',
#  'Linear-Regression-Student-Performance-1.ipynb',
#  'Links',
#  'Local Settings',
#  'Logistic_Regression.ipynb',
#  'Machine_Learning.ipynb',
#  'Microsoft',
#  'mnist.csv',
#  'Module 6 Excercise.ipynb',
#  'Multiple_Logistic_Regression.ipynb',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{68f31326-af3c-11ef-a969-da43caba261a}.TM.blf',
#  'NTUSER.DAT{68f31326-af3c-11ef-a969-da43caba261a}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{68f31326-af3c-11ef-a969-da43caba261a}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'output.mp3',
#  'outputs',
#  'output_plots',
#  'Pictures',
#  'PrintHood',
#  'Random_Forest_Classifier.ipynb',
#  'Recent',
#  'Sample - Superstore.csv',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'source',
#  'spam.csv',
#  'Standard_Scaler.ipynb',
#  'Start Menu',
#  'Super Store Sales Aanalysis.ipynb',
#  'Superstore.csv',
#  'SVM.ipynb',
#  'Telco_Customer_Churn.csv',
#  'temperature-1.csv',
#  'Templates',
#  'Text-Preprocessing-NLP.ipynb',
#  'Text_Classification.ipynb',
#  'Titanic-Dataset.csv',
#  'Titanic_Data_Analysis.ipynb',
#  'titanic_submission.csv',
#  'Twitter_Data.csv',
#  'Untitled Folder',
#  'Untitled Folder 1',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Videos']

# %%
FileLink("E_Commerce_PowerBI.csv")
# Out:
# C:\Users\oanka\E_Commerce_PowerBI.csv
